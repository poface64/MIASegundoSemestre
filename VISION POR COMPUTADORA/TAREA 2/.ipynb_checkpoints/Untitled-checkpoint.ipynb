# %% [markdown]
# # Cargar las librerias necesarias

# %%
# Definir el filtro bilineal
# Parametros de entrada: 
## Imagen de entrada
## Ancho de salida
## Alto de salida
function bilineal(Imagen,Ancho,Alto) 
    # Parametros de salida de la nueva matriz #
    naltura = Ancho
    nancho = Alto
    # Crear la nueva matriz de enteros de tamaño naltura X nancho
    nueva = zeros(Int,naltura,nancho);
    #### Dmensiones originales de la matriz
    Oaltura = size(Imagen)[1]
    Oancho = size(Imagen)[2]
    #### Definir la relación entre los tamaños
    escalaX = (Oancho-1)/(nancho-1);
    escalaY = (Oaltura-1)/(naltura-1);
    #### Aplicación del escalado ####
    for i in 1:naltura
        # Segundo loop
        for j in 1:nancho
            # Coordenadas de la imagen original
            X = escalaX*(j-1) + 1 # Adelante del borde
            Y = escalaY*(i-1) + 1 # Adelante del borde
            ### Datos para hacer el interpolado ###
            ## Coordenadas en X ##
            x1 = floor(Int,X)
            x2 = min(x1+1,Oancho)
            ## Coordenadas en Y ##
            y1 = floor(Int,Y)
            y2 = min(y1+1,Oaltura)
            # Pesos para la interpolación #
            dx = X-x1
            dy = Y-y1
            ### Extraer los valores de los pixeles vecinos ####
            Q11 = Imagen[y1,x1]
            Q12 = Imagen[y2,x1]
            Q21 = Imagen[y1,x2]
            Q22 = Imagen[y2,x2]
            ### Crear el pixel con la interpolación ####
            px = (1-dx)*(1-dy)*Q11 +
                            dx*(1-dy)*Q21 +
                            (1-dx)*dy*Q12 +
                            dx*(dy)*Q22
            # Guardarlo en la matriz de salida #
            nueva[i,j] = round.(Int,px)
        end
    end
    # Devolver la matriz resultante
    # Convertir en escala de grises #
    res = clamp.(nueva./255,0,1);
    # Convertir la matriz en escala de grises
    return(Gray.(res)) 
end
# Out:
# bilineal (generic function with 1 method)

# %%
# Cargar las librerias para el procesado de imagenes
using Images
#using ImageView
# Imagen De referencia
ruta = "IMG/Fig2.19(a).jpg"
img = load(ruta)
img1 = Gray.(img)
# Guardar la imagen
#save("IMG/IM1gray.jpg", img1)
# Out:
# 1024×1024 Array{Gray{N0f8},2} with eltype Gray{N0f8}:
#  Gray{N0f8}(0.082)  Gray{N0f8}(0.063)  …  Gray{N0f8}(0.09)
#  Gray{N0f8}(0.082)  Gray{N0f8}(0.075)     Gray{N0f8}(0.094)
#  Gray{N0f8}(0.067)  Gray{N0f8}(0.067)     Gray{N0f8}(0.09)
#  Gray{N0f8}(0.063)  Gray{N0f8}(0.075)     Gray{N0f8}(0.098)
#  Gray{N0f8}(0.067)  Gray{N0f8}(0.078)     Gray{N0f8}(0.098)
#  Gray{N0f8}(0.067)  Gray{N0f8}(0.082)  …  Gray{N0f8}(0.082)
#  Gray{N0f8}(0.063)  Gray{N0f8}(0.059)     Gray{N0f8}(0.082)
#  Gray{N0f8}(0.082)  Gray{N0f8}(0.082)     Gray{N0f8}(0.09)
#  Gray{N0f8}(0.082)  Gray{N0f8}(0.098)     Gray{N0f8}(0.078)
#  Gray{N0f8}(0.067)  Gray{N0f8}(0.067)     Gray{N0f8}(0.067)
#  Gray{N0f8}(0.078)  Gray{N0f8}(0.063)  …  Gray{N0f8}(0.09)
#  Gray{N0f8}(0.082)  Gray{N0f8}(0.067)     Gray{N0f8}(0.082)
#  Gray{N0f8}(0.067)  Gray{N0f8}(0.055)     Gray{N0f8}(0.094)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.02)   Gray{N0f8}(0.024)     Gray{N0f8}(0.027)
#  Gray{N0f8}(0.02)   Gray{N0f8}(0.024)     Gray{N0f8}(0.047)
#  Gray{N0f8}(0.02)   Gray{N0f8}(0.016)     Gray{N0f8}(0.024)
#  Gray{N0f8}(0.027)  Gray{N0f8}(0.02)   …  Gray{N0f8}(0.024)
#  Gray{N0f8}(0.02)   Gray{N0f8}(0.027)     Gray{N0f8}(0.039)
#  Gray{N0f8}(0.02)   Gray{N0f8}(0.02)      Gray{N0f8}(0.031)
#  Gray{N0f8}(0.024)  Gray{N0f8}(0.031)     Gray{N0f8}(0.031)
#  Gray{N0f8}(0.024)  Gray{N0f8}(0.031)     Gray{N0f8}(0.059)
#  Gray{N0f8}(0.02)   Gray{N0f8}(0.02)   …  Gray{N0f8}(0.059)
#  Gray{N0f8}(0.027)  Gray{N0f8}(0.027)     Gray{N0f8}(0.082)
#  Gray{N0f8}(0.039)  Gray{N0f8}(0.039)     Gray{N0f8}(0.067)
#  Gray{N0f8}(0.043)  Gray{N0f8}(0.039)     Gray{N0f8}(0.059)

# %%
# Imagen De referencia
ruta = "IMG/Fig2.19(a).jpg"
img = load(ruta)
img1 = round.(Int,Gray.(img).* 255);

# %%
res1 = bilineal(img1,4000,4000)
# Out:
# 4000×4000 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.0823529)  …  Gray{Float64}(0.0901961)
#  Gray{Float64}(0.0823529)     Gray{Float64}(0.0901961)
#  Gray{Float64}(0.0823529)     Gray{Float64}(0.0941176)
#  Gray{Float64}(0.0823529)     Gray{Float64}(0.0941176)
#  Gray{Float64}(0.0823529)     Gray{Float64}(0.0941176)
#  Gray{Float64}(0.0784314)  …  Gray{Float64}(0.0941176)
#  Gray{Float64}(0.0745098)     Gray{Float64}(0.0901961)
#  Gray{Float64}(0.0705882)     Gray{Float64}(0.0901961)
#  Gray{Float64}(0.0666667)     Gray{Float64}(0.0901961)
#  Gray{Float64}(0.0666667)     Gray{Float64}(0.0941176)
#  Gray{Float64}(0.0627451)  …  Gray{Float64}(0.0941176)
#  Gray{Float64}(0.0627451)     Gray{Float64}(0.0980392)
#  Gray{Float64}(0.0627451)     Gray{Float64}(0.0980392)
#  ⋮                         ⋱
#  Gray{Float64}(0.0196078)     Gray{Float64}(0.0627451)
#  Gray{Float64}(0.0235294)     Gray{Float64}(0.0705882)
#  Gray{Float64}(0.0235294)  …  Gray{Float64}(0.0745098)
#  Gray{Float64}(0.027451)      Gray{Float64}(0.0823529)
#  Gray{Float64}(0.0313725)     Gray{Float64}(0.0784314)
#  Gray{Float64}(0.0313725)     Gray{Float64}(0.0745098)
#  Gray{Float64}(0.0352941)     Gray{Float64}(0.0705882)
#  Gray{Float64}(0.0392157)  …  Gray{Float64}(0.0666667)
#  Gray{Float64}(0.0392157)     Gray{Float64}(0.0666667)
#  Gray{Float64}(0.0392157)     Gray{Float64}(0.0627451)
#  Gray{Float64}(0.0431373)     Gray{Float64}(0.0627451)
#  Gray{Float64}(0.0431373)     Gray{Float64}(0.0588235)

# %%
save("IMG/res1.jpg", res1)

res2 = bilineal(img1,1000,1000);
save("IMG/res2.jpg", res2)

res3 = bilineal(img1,100,100);
save("IMG/res3.jpg", res3)

res4 = bilineal(img1,10,10);
save("IMG/res4.jpg", res4)
# Out:
# 482
